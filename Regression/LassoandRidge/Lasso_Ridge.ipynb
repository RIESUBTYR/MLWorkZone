# %% [markdown]
# # Lasso and Ridge Regression Testing
#
# <hr></hr>

# %%
import pandas as pd
import seaborn as sns
import numpy as nps
import matplotlib.pyplot as plt
from sklearn import *

#Opening dataset

data = pd.read_csv("train.csv")

print(data.shape)

print(data.columns)

data.head()
# Out:
# (2000, 21)
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# ...

# %%
#Creating Training and Testing datasets

Data_x = data[['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]

Data_y=House_data.loc[:,'price_range']

#split train - test data
train_x,test_x,train_y,test_y=model_selection.train_test_split(Data_x,Data_y,train_size=0.8,random_state=1)

# %%
#train model
regr=linear_model.LinearRegression()
regr.fit(train_x,train_y)


pred_y=regr.predict(test_x)

# pred_y=[round(num) for num in pred_y]

# pred_y=[3 if element>=4 else element for element in pred_y ]
# pred_y=[0 if element<=0 else element for element in pred_y ]


#mse r2score
mse=metrics.mean_squared_error(test_y,pred_y)
rscore=metrics.r2_score(test_y,pred_y)
print('Mean Square Error: {}\n Correlation score: {}'.format(mse,rscore) )
# Out:
# Mean Square Error: 0.11404479325671037
#  Correlation score: 0.907713950147308

# %%
# graphs
plt.scatter(test_x['battery_power'],test_y,color='orange')
plt.scatter(test_x['battery_power'],pred_y,color='blue')
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#Lasso Regression

lasso=linear_model.Lasso(alpha=1)
lasso.fit(train_x,train_y)


pred_y=lasso.predict(test_x)

# pred_y=[round(num) for num in pred_y]
# pred_y=[3 if element>=4 else element for element in pred_y ]
# pred_y=[0 if element<=0 else element for element in pred_y ]

#mse r2score
mse=metrics.mean_squared_error(test_y,pred_y)
rscore=metrics.r2_score(test_y,pred_y)
print('Mean Square Error: {}\n Correlation score: {}'.format(mse,rscore) )
# Out:
# Mean Square Error: 0.11252587377112393
#  Correlation score: 0.9089430731556117

# %%
# graphs
plt.scatter(test_x['battery_power'],test_y,color='orange')
plt.scatter(test_x['battery_power'],pred_y,color='blue')
plt.show()

# %%
#Ridge Regression

ridge=linear_model.Ridge(alpha=1)
ridge.fit(train_x,train_y)


pred_y=ridge.predict(test_x)

# pred_y=[round(num) for num in pred_y]

# pred_y=[3 if element>=4 else element for element in pred_y ]
# pred_y=[0 if element<=0 else element for element in pred_y ]

#mse r2score
mse=metrics.mean_squared_error(test_y,pred_y)
rscore=metrics.r2_score(test_y,pred_y)
print('Mean Square Error: {}\n Correlation score: {}'.format(mse,rscore) )
# Out:
# Mean Square Error: 0.114041796541413
#  Correlation score: 0.9077163751156861

# %%
#graphs
plt.scatter(test_x['battery_power'],test_y,color='orange')
plt.scatter(test_x['battery_power'],pred_y,color='blue')
plt.show()

# %% [markdown]
# # Conclusion
#
# For DataSet of size 2000
#
# ## Linear
#
# ### Score:-0.907713950147308
# ### MSE:-0.11404479325671037
#
# ## Lasso
#
# ### Score:-0.9089430731556117
# ### MSE:-0.11252587377112393
#
# ## Ridge
#
# ### Score:-0.9077163751156861
# ### MSE:-0.114041796541413
